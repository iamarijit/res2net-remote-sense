# %% [markdown]
# # Download Data

# %%
# !wget http://www.patreo.dcc.ufmg.br/wp-content/uploads/2017/11/brazilian_coffee_dataset.zip
# !unzip brazilian_coffee_dataset.zip
# !git clone https://github.com/gasvn/Res2Net.git
# !pip install ipython-autotime
# Out:
# --2020-11-08 12:52:21--  http://www.patreo.dcc.ufmg.br/wp-content/uploads/2017/11/brazilian_coffee_dataset.zip
# Resolving www.patreo.dcc.ufmg.br (www.patreo.dcc.ufmg.br)... 150.164.11.226
# Connecting to www.patreo.dcc.ufmg.br (www.patreo.dcc.ufmg.br)|150.164.11.226|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4796290 (4.6M) [application/zip]
# Saving to: ‘brazilian_coffee_dataset.zip’
#
# brazilian_coffee_da 100%[===================>]   4.57M  2.53MB/s    in 1.8s
#
# 2020-11-08 12:52:24 (2.53 MB/s) - ‘brazilian_coffee_dataset.zip’ saved [4796290/4796290]
#
# Archive:  brazilian_coffee_dataset.zip
#    creating: brazilian_coffee_scenes/
#   inflating: brazilian_coffee_scenes/fold5.txt
#   inflating: brazilian_coffee_scenes/fold4.txt
#   inflating: brazilian_coffee_scenes/fold3.txt
#   inflating: brazilian_coffee_scenes/fold2.txt
#   inflating: brazilian_coffee_scenes/fold1.txt
#    creating: brazilian_coffee_scenes/fold5/
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T7936.B8000.L4288.R4352.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T7872.B7936.L4352.R4416.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T7680.B7744.L4224.R4288.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T7616.B7680.L4736.R4800.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T7616.B7680.L4352.R4416.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T7616.B7680.L2944.R3008.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T7552.B7616.L4480.R4544.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T7488.B7552.L4928.R4992.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T7488.B7552.L4800.R4864.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T7488.B7552.L2112.R2176.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T7296.B7360.L1024.R1088.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T6976.B7040.L512.R576.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T6976.B7040.L1984.R2048.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T6656.B6720.L3840.R3904.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T6528.B6592.L3648.R3712.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T6336.B6400.L4544.R4608.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T6272.B6336.L2304.R2368.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T6208.B6272.L5504.R5568.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T6144.B6208.L2752.R2816.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T5824.B5888.L1984.R2048.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T5760.B5824.L4608.R4672.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T5696.B5760.L4352.R4416.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T5696.B5760.L3392.R3456.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T5504.B5568.L3840.R3904.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T5440.B5504.L3456.R3520.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T5440.B5504.L1984.R2048.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T5376.B5440.L3392.R3456.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T5312.B5376.L2944.R3008.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T5248.B5312.L5952.R6016.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T5248.B5312.L5120.R5184.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T5184.B5248.L2752.R2816.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T5120.B5184.L5376.R5440.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4992.B5056.L6400.R6464.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4864.B4928.L4800.R4864.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4864.B4928.L2944.R3008.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4800.B4864.L6208.R6272.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4800.B4864.L6144.R6208.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4800.B4864.L5888.R5952.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4736.B4800.L7040.R7104.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4736.B4800.L5632.R5696.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4736.B4800.L5568.R5632.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4672.B4736.L5952.R6016.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4672.B4736.L5888.R5952.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4672.B4736.L5632.R5696.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4608.B4672.L5824.R5888.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4608.B4672.L5440.R5504.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4480.B4544.L2304.R2368.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4480.B4544.L1856.R1920.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4416.B4480.L4096.R4160.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4416.B4480.L3328.R3392.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4352.B4416.L6144.R6208.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4288.B4352.L3136.R3200.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4288.B4352.L2624.R2688.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4288.B4352.L2176.R2240.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4224.B4288.L5760.R5824.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4160.B4224.L3712.R3776.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T4032.B4096.L2496.R2560.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T384.B448.L4224.R4288.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T3584.B3648.L6528.R6592.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T3584.B3648.L3648.R3712.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T3520.B3584.L5312.R5376.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T3456.B3520.L6528.R6592.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T3456.B3520.L3776.R3840.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T3392.B3456.L5376.R5440.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T3264.B3328.L6144.R6208.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T3200.B3264.L6208.R6272.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T3200.B3264.L5248.R5312.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T3136.B3200.L6656.R6720.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T3072.B3136.L5568.R5632.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T3008.B3072.L4928.R4992.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T2816.B2880.L5824.R5888.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T2688.B2752.L5568.R5632.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T2560.B2624.L3264.R3328.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T2368.B2432.L5504.R5568.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T2368.B2432.L5376.R5440.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T2368.B2432.L3968.R4032.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T2048.B2112.L4416.R4480.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T1728.B1792.L4608.R4672.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T1472.B1536.L4352.R4416.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T1408.B1472.L4672.R4736.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T128.B192.L4352.R4416.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T1152.B1216.L5632.R5696.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T10944.B11008.L1344.R1408.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T10944.B11008.L1152.R1216.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T1088.B1152.L4352.R4416.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T960.B1024.L4928.R4992.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T960.B1024.L4416.R4480.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T960.B1024.L3840.R3904.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T896.B960.L4416.R4480.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T768.B832.L2240.R2304.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T6080.B6144.L2944.R3008.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T6016.B6080.L3520.R3584.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T5760.B5824.L2304.R2368.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T5504.B5568.L1152.R1216.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T5376.B5440.L3904.R3968.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T5376.B5440.L1408.R1472.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T5312.B5376.L4928.R4992.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T5312.B5376.L4672.R4736.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T5120.B5184.L512.R576.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T5120.B5184.L1472.R1536.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T5056.B5120.L3456.R3520.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T4736.B4800.L2752.R2816.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T4608.B4672.L3584.R3648.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T4352.B4416.L4032.R4096.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T4288.B4352.L4608.R4672.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T4160.B4224.L5248.R5312.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T4160.B4224.L3840.R3904.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T3968.B4032.L4288.R4352.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T3776.B3840.L2240.R2304.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T3584.B3648.L4288.R4352.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T3584.B3648.L4096.R4160.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T3520.B3584.L2240.R2304.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T2816.B2880.L5056.R5120.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T2752.B2816.L1600.R1664.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T2560.B2624.L2176.R2240.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T2432.B2496.L5184.R5248.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T2432.B2496.L4992.R5056.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T2432.B2496.L4096.R4160.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T2368.B2432.L4992.R5056.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T2304.B2368.L4992.R5056.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T2240.B2304.L1920.R1984.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T2176.B2240.L4416.R4480.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T1984.B2048.L1984.R2048.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T1984.B2048.L1664.R1728.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T1920.B1984.L3072.R3136.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T1536.B1600.L4736.R4800.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T1472.B1536.L4928.R4992.jpg
#   inflating: brazilian_coffee_scenes/fold5/arceburgo.T1472.B1536.L2112.R2176.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T9152.B9216.L2304.R2368.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T9024.B9088.L3008.R3072.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T8960.B9024.L2944.R3008.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T8768.B8832.L2496.R2560.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T8576.B8640.L704.R768.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T8512.B8576.L5248.R5312.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T8448.B8512.L3136.R3200.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T8320.B8384.L3648.R3712.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T8256.B8320.L5632.R5696.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T8256.B8320.L1216.R1280.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T8192.B8256.L640.R704.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T8192.B8256.L5696.R5760.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T8128.B8192.L5056.R5120.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T8128.B8192.L4416.R4480.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T8064.B8128.L5056.R5120.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T8064.B8128.L1472.R1536.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T8064.B8128.L1344.R1408.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T7936.B8000.L4608.R4672.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T7936.B8000.L1472.R1536.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T768.B832.L5504.R5568.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T7552.B7616.L1664.R1728.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T7488.B7552.L960.R1024.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T7488.B7552.L3840.R3904.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T7488.B7552.L2240.R2304.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T7424.B7488.L4672.R4736.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T7296.B7360.L5696.R5760.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T7232.B7296.L0.R64.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T7104.B7168.L1664.R1728.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T7040.B7104.L2880.R2944.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T7040.B7104.L128.R192.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T6720.B6784.L3328.R3392.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T6656.B6720.L320.R384.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T6592.B6656.L2368.R2432.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T6592.B6656.L1728.R1792.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T6528.B6592.L2368.R2432.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T6464.B6528.L6272.R6336.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T6336.B6400.L1856.R1920.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T6272.B6336.L4672.R4736.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T6208.B6272.L960.R1024.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T6208.B6272.L5312.R5376.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T6144.B6208.L5056.R5120.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T6016.B6080.L4224.R4288.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5952.B6016.L6144.R6208.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5888.B5952.L6400.R6464.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5888.B5952.L6208.R6272.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5888.B5952.L6080.R6144.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5888.B5952.L5248.R5312.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5824.B5888.L6080.R6144.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5824.B5888.L5504.R5568.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5824.B5888.L4416.R4480.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5696.B5760.L3520.R3584.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5696.B5760.L1024.R1088.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5632.B5696.L5376.R5440.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5632.B5696.L4160.R4224.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5568.B5632.L5568.R5632.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5568.B5632.L1728.R1792.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5568.B5632.L1536.R1600.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5504.B5568.L5888.R5952.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5440.B5504.L6016.R6080.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5312.B5376.L1664.R1728.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5248.B5312.L1728.R1792.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5184.B5248.L5952.R6016.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5184.B5248.L5312.R5376.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T5056.B5120.L4352.R4416.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T4800.B4864.L832.R896.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T4800.B4864.L6144.R6208.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T4800.B4864.L3712.R3776.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T4736.B4800.L2048.R2112.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T4480.B4544.L4224.R4288.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T448.B512.L5376.R5440.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T4416.B4480.L1728.R1792.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T4288.B4352.L3136.R3200.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T4224.B4288.L1472.R1536.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T4096.B4160.L2880.R2944.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T3776.B3840.L2880.R2944.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T3648.B3712.L6080.R6144.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T3584.B3648.L3712.R3776.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T3456.B3520.L5440.R5504.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T3456.B3520.L2432.R2496.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T3392.B3456.L3776.R3840.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T3200.B3264.L6016.R6080.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T3200.B3264.L4800.R4864.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T3200.B3264.L4608.R4672.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T3200.B3264.L4224.R4288.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T3200.B3264.L3456.R3520.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T3200.B3264.L2496.R2560.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T320.B384.L5376.R5440.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T3136.B3200.L1984.R2048.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T3072.B3136.L5504.R5568.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T2944.B3008.L3328.R3392.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T2816.B2880.L2368.R2432.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T2688.B2752.L4288.R4352.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T2496.B2560.L5568.R5632.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T2496.B2560.L3264.R3328.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T2432.B2496.L4288.R4352.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T2368.B2432.L3968.R4032.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T2304.B2368.L4032.R4096.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T2176.B2240.L5632.R5696.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T2112.B2176.L2624.R2688.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T1984.B2048.L2816.R2880.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T1920.B1984.L4544.R4608.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T1792.B1856.L2688.R2752.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T1472.B1536.L5056.R5120.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T1408.B1472.L1984.R2048.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T1344.B1408.L1920.R1984.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T1344.B1408.L1728.R1792.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T1280.B1344.L2496.R2560.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T1280.B1344.L1984.R2048.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T1216.B1280.L1984.R2048.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T1216.B1280.L1920.R1984.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T1088.B1152.L2304.R2368.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T9920.B9984.L2496.R2560.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T9536.B9600.L1024.R1088.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T9408.B9472.L2944.R3008.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T9344.B9408.L768.R832.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T9216.B9280.L5056.R5120.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T9216.B9280.L3136.R3200.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T9152.B9216.L4096.R4160.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T9088.B9152.L4928.R4992.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T9024.B9088.L1472.R1536.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T8704.B8768.L1344.R1408.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T8640.B8704.L1664.R1728.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T8640.B8704.L1344.R1408.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T8448.B8512.L4992.R5056.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T8384.B8448.L3072.R3136.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T8256.B8320.L2688.R2752.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T8064.B8128.L3776.R3840.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaranesia.T8064.B8128.L1664.R1728.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6336.B6400.L4224.R4288.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6208.B6272.L7744.R7808.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6208.B6272.L768.R832.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6208.B6272.L7488.R7552.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6208.B6272.L5504.R5568.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6144.B6208.L5632.R5696.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6144.B6208.L3840.R3904.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6016.B6080.L8576.R8640.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6016.B6080.L7168.R7232.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5952.B6016.L8000.R8064.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5952.B6016.L7744.R7808.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5952.B6016.L1408.R1472.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5888.B5952.L8960.R9024.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5888.B5952.L7232.R7296.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5888.B5952.L10560.R10624.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5824.B5888.L7552.R7616.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5824.B5888.L3840.R3904.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5760.B5824.L768.R832.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5696.B5760.L5056.R5120.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5696.B5760.L4800.R4864.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5632.B5696.L9408.R9472.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5568.B5632.L7296.R7360.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5568.B5632.L7040.R7104.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5504.B5568.L8192.R8256.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5504.B5568.L256.R320.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5440.B5504.L9088.R9152.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5440.B5504.L8064.R8128.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5376.B5440.L8192.R8256.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5376.B5440.L1856.R1920.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5312.B5376.L448.R512.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5248.B5312.L1472.R1536.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5248.B5312.L12608.R12672.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5248.B5312.L12416.R12480.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5184.B5248.L8704.R8768.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5184.B5248.L12608.R12672.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5120.B5184.L640.R704.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5120.B5184.L11456.R11520.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T512.B576.L10240.R10304.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5056.B5120.L9216.R9280.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5056.B5120.L640.R704.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5056.B5120.L448.R512.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5056.B5120.L384.R448.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5056.B5120.L3776.R3840.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5056.B5120.L3264.R3328.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T5056.B5120.L3136.R3200.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4992.B5056.L7296.R7360.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4864.B4928.L1856.R1920.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4800.B4864.L3328.R3392.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4800.B4864.L12032.R12096.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4736.B4800.L512.R576.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4736.B4800.L12160.R12224.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4672.B4736.L6400.R6464.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4672.B4736.L3584.R3648.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4672.B4736.L2176.R2240.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4608.B4672.L10240.R10304.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4608.B4672.L10176.R10240.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4608.B4672.L10112.R10176.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4608.B4672.L10048.R10112.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4544.B4608.L9984.R10048.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4544.B4608.L9920.R9984.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4544.B4608.L9536.R9600.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4544.B4608.L8320.R8384.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4416.B4480.L7744.R7808.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4416.B4480.L6912.R6976.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4416.B4480.L448.R512.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4352.B4416.L5696.R5760.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4288.B4352.L960.R1024.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4288.B4352.L1024.R1088.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4224.B4288.L7744.R7808.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4096.B4160.L8896.R8960.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T4096.B4160.L4224.R4288.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3968.B4032.L5376.R5440.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3968.B4032.L11392.R11456.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3904.B3968.L13376.R13440.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3840.B3904.L9792.R9856.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3776.B3840.L2496.R2560.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3776.B3840.L13888.R13952.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3712.B3776.L9600.R9664.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3712.B3776.L5248.R5312.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3712.B3776.L3328.R3392.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3520.B3584.L8896.R8960.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3520.B3584.L12160.R12224.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3456.B3520.L12992.R13056.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3456.B3520.L12480.R12544.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3392.B3456.L12480.R12544.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3328.B3392.L7872.R7936.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3328.B3392.L13248.R13312.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3328.B3392.L12416.R12480.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3200.B3264.L11264.R11328.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3200.B3264.L10816.R10880.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T320.B384.L10112.R10176.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3072.B3136.L13056.R13120.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3008.B3072.L13312.R13376.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T3008.B3072.L10624.R10688.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T2880.B2944.L10432.R10496.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T2752.B2816.L12224.R12288.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T2752.B2816.L11136.R11200.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T2688.B2752.L6208.R6272.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T2560.B2624.L10432.R10496.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T2496.B2560.L6848.R6912.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T2496.B2560.L11392.R11456.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T2432.B2496.L13376.R13440.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T2304.B2368.L6720.R6784.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T2176.B2240.L6976.R7040.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T2176.B2240.L10432.R10496.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T2112.B2176.L12736.R12800.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T2048.B2112.L8448.R8512.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T1920.B1984.L12992.R13056.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T1664.B1728.L11136.R11200.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T1344.B1408.L8960.R9024.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T12480.B12544.L4864.R4928.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T12416.B12480.L4992.R5056.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T12352.B12416.L5184.R5248.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T12352.B12416.L4480.R4544.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T12032.B12096.L5184.R5248.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T11840.B11904.L6144.R6208.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T11392.B11456.L4352.R4416.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T1088.B1152.L8192.R8256.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T10304.B10368.L5568.R5632.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T10304.B10368.L4544.R4608.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T10240.B10304.L8192.R8256.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T10240.B10304.L5568.R5632.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T10176.B10240.L9024.R9088.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T10176.B10240.L7616.R7680.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T10048.B10112.L8320.R8384.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T9920.B9984.L2560.R2624.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T9408.B9472.L2624.R2688.jpg
#   inflating: brazilian_coffee_scenes/fold5/guaxupe.T9344.B9408.L2368.R2432.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T9856.B9920.L8896.R8960.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T9856.B9920.L6464.R6528.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T9856.B9920.L5504.R5568.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T9728.B9792.L6912.R6976.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T9728.B9792.L3968.R4032.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T9600.B9664.L5312.R5376.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T9600.B9664.L4992.R5056.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T9600.B9664.L3968.R4032.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T960.B1024.L7680.R7744.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T9536.B9600.L8192.R8256.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T9536.B9600.L5312.R5376.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T9536.B9600.L5184.R5248.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T9536.B9600.L4800.R4864.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T9472.B9536.L4800.R4864.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T9472.B9536.L3712.R3776.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T9408.B9472.L4864.R4928.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T9216.B9280.L9216.R9280.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T9216.B9280.L5440.R5504.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8896.B8960.L5632.R5696.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8832.B8896.L5696.R5760.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8768.B8832.L6720.R6784.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8768.B8832.L5824.R5888.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8704.B8768.L6400.R6464.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8704.B8768.L5696.R5760.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8448.B8512.L4224.R4288.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8448.B8512.L3648.R3712.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8448.B8512.L3328.R3392.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8384.B8448.L7104.R7168.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8384.B8448.L3968.R4032.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8384.B8448.L3712.R3776.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8320.B8384.L4544.R4608.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T832.B896.L7360.R7424.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8256.B8320.L4160.R4224.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8192.B8256.L6592.R6656.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8192.B8256.L4224.R4288.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8192.B8256.L3328.R3392.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8128.B8192.L6976.R7040.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8128.B8192.L5952.R6016.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8128.B8192.L4544.R4608.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8064.B8128.L4608.R4672.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8064.B8128.L3584.R3648.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8064.B8128.L2816.R2880.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8064.B8128.L10048.R10112.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T8000.B8064.L4928.R4992.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7936.B8000.L5120.R5184.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7936.B8000.L4928.R4992.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7936.B8000.L4800.R4864.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7936.B8000.L4224.R4288.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7872.B7936.L9088.R9152.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7808.B7872.L6592.R6656.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7808.B7872.L6080.R6144.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7808.B7872.L4928.R4992.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7808.B7872.L3520.R3584.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7808.B7872.L10752.R10816.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7744.B7808.L3456.R3520.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7744.B7808.L10240.R10304.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7552.B7616.L6080.R6144.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7488.B7552.L6016.R6080.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7424.B7488.L10688.R10752.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7360.B7424.L6016.R6080.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7232.B7296.L8192.R8256.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7232.B7296.L6528.R6592.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7040.B7104.L9536.R9600.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7040.B7104.L5184.R5248.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7040.B7104.L4352.R4416.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T7040.B7104.L11200.R11264.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T704.B768.L7872.R7936.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6976.B7040.L8832.R8896.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6912.B6976.L9536.R9600.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6912.B6976.L9472.R9536.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6912.B6976.L9088.R9152.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6784.B6848.L8000.R8064.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6784.B6848.L1664.R1728.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6720.B6784.L8832.R8896.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6720.B6784.L7936.R8000.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6720.B6784.L2304.R2368.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6720.B6784.L1536.R1600.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6656.B6720.L4480.R4544.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6656.B6720.L2560.R2624.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6656.B6720.L11648.R11712.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6656.B6720.L10112.R10176.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6592.B6656.L9024.R9088.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6592.B6656.L7552.R7616.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6528.B6592.L4608.R4672.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6528.B6592.L4352.R4416.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6528.B6592.L4224.R4288.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6464.B6528.L8512.R8576.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6464.B6528.L4544.R4608.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6400.B6464.L6912.R6976.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6400.B6464.L5440.R5504.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6336.B6400.L7808.R7872.jpg
#   inflating: brazilian_coffee_scenes/fold5/montesanto.T6336.B6400.L4288.R4352.jpg
#    creating: brazilian_coffee_scenes/fold4/
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4928.B4992.L2752.R2816.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4864.B4928.L2752.R2816.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4864.B4928.L2304.R2368.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4800.B4864.L5952.R6016.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4800.B4864.L3904.R3968.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4736.B4800.L5888.R5952.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4736.B4800.L3008.R3072.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4672.B4736.L5568.R5632.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4672.B4736.L5440.R5504.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4608.B4672.L5888.R5952.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4608.B4672.L5504.R5568.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4544.B4608.L5696.R5760.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4544.B4608.L5376.R5440.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4416.B4480.L6656.R6720.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4416.B4480.L3904.R3968.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4416.B4480.L3712.R3776.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4352.B4416.L3840.R3904.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4288.B4352.L1664.R1728.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4224.B4288.L4032.R4096.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4096.B4160.L6464.R6528.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T4032.B4096.L6272.R6336.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3968.B4032.L6976.R7040.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3968.B4032.L3904.R3968.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3904.B3968.L6464.R6528.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3904.B3968.L5952.R6016.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3840.B3904.L5248.R5312.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3840.B3904.L2752.R2816.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3776.B3840.L4992.R5056.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3584.B3648.L5120.R5184.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3584.B3648.L5056.R5120.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3584.B3648.L2752.R2816.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3520.B3584.L7360.R7424.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3520.B3584.L5184.R5248.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3520.B3584.L5120.R5184.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3520.B3584.L2560.R2624.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3456.B3520.L5056.R5120.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3328.B3392.L3200.R3264.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3264.B3328.L5248.R5312.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3200.B3264.L4288.R4352.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3200.B3264.L4032.R4096.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3136.B3200.L5440.R5504.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3136.B3200.L3520.R3584.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3136.B3200.L3200.R3264.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3008.B3072.L5248.R5312.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T3008.B3072.L4160.R4224.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T2944.B3008.L3776.R3840.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T2880.B2944.L5760.R5824.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T2816.B2880.L3008.R3072.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T2752.B2816.L6272.R6336.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T2368.B2432.L2816.R2880.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T2304.B2368.L3328.R3392.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T2176.B2240.L5952.R6016.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T2112.B2176.L2880.R2944.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T2048.B2112.L6464.R6528.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T1984.B2048.L6528.R6592.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T1984.B2048.L4800.R4864.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T192.B256.L3776.R3840.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T1600.B1664.L6528.R6592.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T1536.B1600.L4800.R4864.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T1344.B1408.L4992.R5056.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T1280.B1344.L5120.R5184.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T1152.B1216.L5440.R5504.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T1152.B1216.L4928.R4992.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T11072.B11136.L1152.R1216.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T11008.B11072.L896.R960.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T10688.B10752.L960.R1024.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T10496.B10560.L1472.R1536.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T10432.B10496.L512.R576.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T10432.B10496.L320.R384.jpg
#   inflating: brazilian_coffee_scenes/fold4/guaranesia.T10240.B10304.L1856.R1920.jpg
#   inflating: brazilian_coffee_scenes/fold4/arceburgo.T960.B1024.L3648.R3712.jpg
#   inflating: brazilian_coffee_scenes/fold4/arceburgo.T896.B960.L4736.R4800.jpg
#   inflating: brazilian_coffee_scenes/fold4/arceburgo.T896.B960.L4480.R4544.jpg
#   inflating: brazilian_coffee_scenes/fold4/arceburgo.T832.B896.L4032.R4096.jpg
#   inflating: brazilian_coffee_scenes/fold4/arceburgo.T768.B832.L3776.R3840.jpg
#   inflating: brazilian_coffee_scenes/fold4/arceburgo.T704.B768.L2624.R2688.jpg
#   inflating: brazilian_coffee_scenes/fold4/arceburgo.T6208.B6272.L768.R832.jpg
#   inflating: brazilian_coffee_scenes/fold4/arceburgo.T6080.B6144.L2880.R2944.jpg
#   inflating: brazilian_coffee_scenes/fold4/arceburgo.T6016.B6080.L640.R704.jpg
#   inflating: brazilian_coffee_scenes/fold4/arceburgo.T6016.B6080.L2624.R2688.jpg
#   inflating: brazilian_coffee_scenes/fold4/arceburgo.T5824.B5888.L4032.R4096.jpg
#   inflating: brazilian_coffee_scenes/fold4/arceburgo.T5632.B5696.L1408.R1472.jpg
#   inflating: brazilian_coffee_scenes/fold4/arceburgo.T5440.B5504.L4160.R4224.jpg
#   inflating: brazilian_coffee_scenes/fold4/arceburgo.T5312.B5376.L448.R512.jpg
#   inflating: brazilian_coffee_scenes/fold4/arceburgo.T5120.B5184.L1088.R1152.jpg
#   inflating: brazilian_coffee_scenes/fold4/arceburgo.T5056.B5120.L3776.R3840.jpg
#   inflating: brazilian_coffee_scenes/fold4/arceburgo.T4992.B5056.L2048.R2112.jpg
# ...
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5568.B5632.L11520.R11584.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5504.B5568.L7936.R8000.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5504.B5568.L4416.R4480.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5504.B5568.L3264.R3328.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5504.B5568.L1984.R2048.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5440.B5504.L8128.R8192.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5440.B5504.L1088.R1152.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5376.B5440.L8064.R8128.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5376.B5440.L4160.R4224.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5376.B5440.L4096.R4160.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5376.B5440.L10496.R10560.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5312.B5376.L1344.R1408.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5312.B5376.L10880.R10944.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5248.B5312.L9856.R9920.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5248.B5312.L1344.R1408.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5248.B5312.L1280.R1344.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5248.B5312.L1152.R1216.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5184.B5248.L6528.R6592.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5184.B5248.L5888.R5952.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5184.B5248.L1408.R1472.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5184.B5248.L1280.R1344.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5184.B5248.L11712.R11776.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5184.B5248.L10880.R10944.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5120.B5184.L1344.R1408.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5056.B5120.L832.R896.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5056.B5120.L7488.R7552.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5056.B5120.L3200.R3264.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5056.B5120.L2240.R2304.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5056.B5120.L2112.R2176.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5056.B5120.L1536.R1600.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5056.B5120.L1408.R1472.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T5056.B5120.L1344.R1408.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4992.B5056.L7232.R7296.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4992.B5056.L3200.R3264.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4992.B5056.L12864.R12928.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4992.B5056.L11008.R11072.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4928.B4992.L4224.R4288.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4928.B4992.L3264.R3328.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4928.B4992.L12864.R12928.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4928.B4992.L11072.R11136.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4864.B4928.L9856.R9920.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4864.B4928.L9792.R9856.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4864.B4928.L7872.R7936.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4800.B4864.L8640.R8704.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4800.B4864.L1856.R1920.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4800.B4864.L1536.R1600.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4736.B4800.L6528.R6592.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4736.B4800.L5632.R5696.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4672.B4736.L2944.R3008.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4672.B4736.L12032.R12096.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4608.B4672.L12672.R12736.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4544.B4608.L4608.R4672.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4544.B4608.L1472.R1536.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4544.B4608.L11840.R11904.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4544.B4608.L10048.R10112.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4480.B4544.L6976.R7040.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4480.B4544.L6912.R6976.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4416.B4480.L768.R832.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4416.B4480.L5120.R5184.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4416.B4480.L1792.R1856.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4352.B4416.L8128.R8192.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4288.B4352.L7232.R7296.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4224.B4288.L9792.R9856.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4224.B4288.L4672.R4736.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4224.B4288.L13056.R13120.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4224.B4288.L10304.R10368.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4160.B4224.L4096.R4160.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4160.B4224.L2368.R2432.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4096.B4160.L8576.R8640.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4096.B4160.L13952.R14016.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4032.B4096.L6336.R6400.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T4032.B4096.L6208.R6272.jpg
#   inflating: brazilian_coffee_scenes/fold1/Thumbs.db
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T9984.B10048.L7552.R7616.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T9920.B9984.L4160.R4224.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T9856.B9920.L9664.R9728.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T9600.B9664.L8576.R8640.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T9600.B9664.L4864.R4928.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T960.B1024.L9472.R9536.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T9536.B9600.L5248.R5312.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T9536.B9600.L5120.R5184.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T9536.B9600.L5056.R5120.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T9472.B9536.L5120.R5184.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T9472.B9536.L4864.R4928.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T9344.B9408.L6976.R7040.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T9344.B9408.L6464.R6528.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T9216.B9280.L6912.R6976.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T9216.B9280.L6720.R6784.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T9216.B9280.L6592.R6656.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T9088.B9152.L5632.R5696.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T9024.B9088.L9152.R9216.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8960.B9024.L8960.R9024.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8960.B9024.L8320.R8384.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8960.B9024.L5568.R5632.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8960.B9024.L10240.R10304.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8832.B8896.L6912.R6976.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8704.B8768.L9472.R9536.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8704.B8768.L6784.R6848.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8704.B8768.L5760.R5824.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8576.B8640.L5952.R6016.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8576.B8640.L4032.R4096.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8576.B8640.L3648.R3712.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8512.B8576.L9984.R10048.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8512.B8576.L3264.R3328.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8512.B8576.L10368.R10432.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8512.B8576.L10112.R10176.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8448.B8512.L4288.R4352.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8448.B8512.L4096.R4160.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8448.B8512.L3968.R4032.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8448.B8512.L3712.R3776.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8384.B8448.L3904.R3968.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8320.B8384.L4288.R4352.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8320.B8384.L4160.R4224.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8320.B8384.L4096.R4160.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8320.B8384.L4032.R4096.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8256.B8320.L6272.R6336.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8256.B8320.L4288.R4352.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8256.B8320.L4096.R4160.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8256.B8320.L4032.R4096.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8256.B8320.L3968.R4032.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8192.B8256.L9152.R9216.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8192.B8256.L7040.R7104.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8192.B8256.L6272.R6336.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8192.B8256.L4544.R4608.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8192.B8256.L4288.R4352.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8192.B8256.L4032.R4096.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8128.B8192.L8512.R8576.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8128.B8192.L6848.R6912.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8128.B8192.L4352.R4416.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8128.B8192.L4288.R4352.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8064.B8128.L7360.R7424.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8064.B8128.L4928.R4992.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8064.B8128.L2112.R2176.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8064.B8128.L10880.R10944.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8000.B8064.L8704.R8768.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8000.B8064.L7168.R7232.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8000.B8064.L4608.R4672.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T8000.B8064.L2048.R2112.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7936.B8000.L9536.R9600.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7936.B8000.L10176.R10240.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7872.B7936.L9024.R9088.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7872.B7936.L8832.R8896.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7872.B7936.L7872.R7936.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7872.B7936.L5248.R5312.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7872.B7936.L4800.R4864.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7872.B7936.L4736.R4800.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7872.B7936.L3328.R3392.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7872.B7936.L10816.R10880.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7808.B7872.L3392.R3456.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7808.B7872.L10240.R10304.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7744.B7808.L2048.R2112.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7744.B7808.L10176.R10240.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7680.B7744.L6144.R6208.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7680.B7744.L3136.R3200.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T768.B832.L7936.R8000.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7616.B7680.L7744.R7808.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7552.B7616.L10752.R10816.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7424.B7488.L3520.R3584.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7360.B7424.L5504.R5568.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7360.B7424.L3776.R3840.jpg
#   inflating: brazilian_coffee_scenes/fold1/montesanto.T7296.B7360.L8192.R8256.jpg
# Cloning into 'Res2Net'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 124 (delta 2), reused 0 (delta 0), pack-reused 118
# Receiving objects: 100% (124/124), 61.74 KiB | 665.00 KiB/s, done.
# Resolving deltas: 100% (73/73), done.
# Collecting ipython-autotime
#   Downloading https://files.pythonhosted.org/packages/3f/58/a4a65efcce5c81a67b6893ade862736de355a3a718af5533d30c991831ce/ipython_autotime-0.2.0-py2.py3-none-any.whl
# Requirement already satisfied: ipython in /usr/local/lib/python3.6/dist-packages (from ipython-autotime) (5.5.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (1.0.18)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (4.3.3)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (0.8.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (50.3.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython->ipython-autotime) (0.6.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->ipython-autotime) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->ipython-autotime) (1.15.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->ipython->ipython-autotime) (0.2.0)
# Installing collected packages: ipython-autotime
# Successfully installed ipython-autotime-0.2.0

# %% [markdown]
# # Import Libraries

# %%
import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import ConcatDataset
import torchvision.transforms as transforms
from torchvision import models
from torchvision import utils
from torchsummary import summary
import torch.nn.functional as F

import numpy as np
from PIL import Image
from keras.utils import to_categorical 
import os
import math
import random
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import seaborn as sb
import matplotlib.pyplot as plt

from IPython.display import clear_output
from google.colab import files

from Res2Net import res2net

# %load_ext autotime
# Out:
# time: 147 µs

# %% [markdown]
# # Define Dataset

# %%
BASE_PATH = "./brazilian_coffee_scenes"
CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda") if CUDA else torch.device("cpu")
FOLDS = ['fold1', 'fold2', 'fold3', 'fold4', 'fold5']
LABEL_DICT = {
    'coffee' : 0, 
    'noncoffee' : 1
    }
LABELS = list(LABEL_DICT.keys())
N_FOLD = 5
BATCH_SIZE = 200
CLASSES = 2
LEARNING_RATE = 0.0001
EPOCHS = 60
# Out:
# time: 92 ms

# %%
class ProcessTrainImage(object):
  def __call__(self, sample):
    image_transformations = transforms.Compose([
                                          transforms.ToPILImage(),
                                          transforms.RandomHorizontalFlip(),
                                          transforms.RandomVerticalFlip(),
                                          transforms.RandomRotation(degrees=90),
                                          transforms.ToTensor(),
                                          transforms.Normalize(
                                              mean=[0.485, 0.456, 0.406],
                                              std=[0.229, 0.224, 0.225]
                                              )
                                          ])

    image, label = sample['image'], sample['label']
    transformed_image = image_transformations(image)
    transformed_label = to_categorical(label, num_classes=CLASSES)

    transformed_sample = {
        'image': transformed_image,
        'label': transformed_label
    }
    return transformed_sample
# Out:
# time: 8.56 ms

# %%
class ProcessTestImage(object):
  def __call__(self, sample):
    image_transformations = transforms.Compose([
                                          transforms.ToPILImage(),
                                          transforms.ToTensor(),
                                          transforms.Normalize(
                                              mean=[0.485, 0.456, 0.406],
                                              std=[0.229, 0.224, 0.225]
                                              )
                                          ])

    image, label = sample['image'], sample['label']
    transformed_image = image_transformations(image)
    transformed_label = to_categorical(label, num_classes=CLASSES)

    transformed_sample = {
        'image': transformed_image,
        'label': transformed_label
    }
    return transformed_sample
# Out:
# time: 10.4 ms

# %%
class BCSDataset(Dataset):
  def __init__(self, fold, label_dict, transform=None):
    self.image_paths, self.image_labels = self.read_fold(fold)
    self.transform = transform
    self.label_dict = label_dict
  
  def __len__(self):
    return len(self.image_labels)

  def __getitem__(self, index):
    image = np.array(Image.open(self.image_paths[index]))
    label = self.label_dict[self.image_labels[index]]

    data = {'image':image, 'label':label}

    if self.transform:
      data = self.transform(data)
    return data

  def read_fold(self, fold):
    image_paths = []
    image_label = []

    text_path = os.path.join(BASE_PATH, fold+'.txt')
    file_txt = open(text_path, 'r')
    
    for f in file_txt.readlines():
      label = f.split('.')[0]
      name = ".".join(f.split('.')[1:])
      name = name.strip('\n') + '.jpg'
      image_path = os.path.join(BASE_PATH, fold, name)
      image_paths.append(image_path)
      image_label.append(label)
      #print(label)

    return image_paths, image_label
# Out:
# time: 40 ms

# %%
def create_train_test_loaders(batch_size, test_fold='fold1'):
  train_folds = [BCSDataset(fold, LABEL_DICT, ProcessTrainImage()) for fold in FOLDS if fold != test_fold]
  
  train_set = ConcatDataset(train_folds)
  test_set = BCSDataset(test_fold, LABEL_DICT, ProcessTestImage())

  train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
  test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)

  return train_loader, test_loader
# Out:
# time: 9.38 ms

# %%
train_loader, test_loader = create_train_test_loaders(BATCH_SIZE, test_fold='fold1')

print("Train Loader")
for data in train_loader:
  image_batch = data['image']
  label_batch = data['label']  
  print(image_batch.shape, label_batch.shape)

print("")

print("Test Loader")
for data in test_loader:
  print(data['image'].shape, data['label'].shape)
# Out:
# Train Loader
# torch.Size([200, 3, 64, 64]) torch.Size([200, 2])
# torch.Size([200, 3, 64, 64]) torch.Size([200, 2])
# torch.Size([200, 3, 64, 64]) torch.Size([200, 2])
# torch.Size([200, 3, 64, 64]) torch.Size([200, 2])
# torch.Size([200, 3, 64, 64]) torch.Size([200, 2])
# torch.Size([200, 3, 64, 64]) torch.Size([200, 2])
# torch.Size([200, 3, 64, 64]) torch.Size([200, 2])
# torch.Size([200, 3, 64, 64]) torch.Size([200, 2])
# torch.Size([200, 3, 64, 64]) torch.Size([200, 2])
# torch.Size([200, 3, 64, 64]) torch.Size([200, 2])
# torch.Size([200, 3, 64, 64]) torch.Size([200, 2])
# torch.Size([76, 3, 64, 64]) torch.Size([76, 2])
#
# Test Loader
# torch.Size([200, 3, 64, 64]) torch.Size([200, 2])
# torch.Size([200, 3, 64, 64]) torch.Size([200, 2])
# torch.Size([200, 3, 64, 64]) torch.Size([200, 2])
# time: 2.51 s

# %% [markdown]
# # Define Pretrained Models

# %%
def freeze_params(parameters):
  for param in parameters:
    param.requires_grad = False
# Out:
# time: 2.07 ms

# %%
def unfreeze_params(parameters):
  for param in parameters:
    param.requires_grad = True
# Out:
# time: 1.63 ms

# %%
def transfer_model(pretrained_model, layers_to_train):
  model = pretrained_model(pretrained=True)

  model.fc = nn.Linear(model.fc.in_features, CLASSES)

  freeze_params(model.parameters())

  if layers_to_train=="last_layer":
    params = model.fc.parameters()
  
  if layers_to_train=="all":
    params = model.parameters()
  
  unfreeze_params(params)

  return model.to(DEVICE)
# Out:
# time: 8.27 ms

# %%
def pretrained_res2net50_14w_8s(layers_to_train="all"):
  model = transfer_model(res2net.res2net50_14w_8s, layers_to_train)
  return model
# Out:
# time: 1.75 ms

# %%
def pretrained_res2net50_26w_4s(layers_to_train="all"):
  model = transfer_model(res2net.res2net50_26w_4s, layers_to_train)
  return model
# Out:
# time: 2.54 ms

# %%
def pretrained_res2net50_26w_6s(layers_to_train="all"):
  model = transfer_model(res2net.res2net50_26w_6s, layers_to_train)
  return model
# Out:
# time: 2.06 ms

# %%
def pretrained_res2net50_26w_8s(layers_to_train="all"):
  model = transfer_model(res2net.res2net50_26w_8s, layers_to_train)
  return model
# Out:
# time: 2.08 ms

# %%
def pretrained_res2net50_48w_2s(layers_to_train="all"):
  model = transfer_model(res2net.res2net50_48w_2s, layers_to_train)
  return model
# Out:
# time: 3.11 ms

# %%
def pretrained_resnet50(layers_to_train="all"):
  model = transfer_model(models.resnet50, layers_to_train)
  return model
# Out:
# time: 2.09 ms

# %%
all_models = {
    'resnet50' : pretrained_resnet50,    
    'res2net50_14w_8s' : pretrained_res2net50_14w_8s,
    'res2net50_26w_4s' : pretrained_res2net50_26w_4s,
    'res2net50_26w_6s' : pretrained_res2net50_26w_6s,
    'res2net50_26w_8s' : pretrained_res2net50_26w_8s,
    'res2net50_48w_2s' : pretrained_res2net50_48w_2s
}
# Out:
# time: 2.49 ms

# %% [markdown]
# # Train Model

# %%
def test_model(model, test_loader, criterion, device):
  test_accuracy = 0
  test_loss = 0
  true_labels = []
  pred_labels = []

  model.eval()
  for batch in test_loader:
    image_batch = batch['image'].to(device)
    label_batch = batch['label'].to(device)
    _, label_batch = torch.max(label_batch, 1)

    y_pred = model(image_batch)
    batch_loss = criterion(y_pred, label_batch)

    _, output_labels = torch.max(y_pred, 1)
    correct = label_batch.eq(output_labels).cpu().numpy()

    test_accuracy += sum(correct)
    test_loss += batch_loss.item() * image_batch.size(0)

    true_labels += list(label_batch.cpu().numpy())
    pred_labels += list(output_labels.cpu().numpy())

  average_testing_loss = test_loss / len(test_loader.sampler)
  average_testing_accuracy = test_accuracy / len(test_loader.sampler)

  return average_testing_loss, average_testing_accuracy, true_labels, pred_labels
# Out:
# time: 25.2 ms

# %%
def train_model(model, train_loader, test_loader, optimizer, criterion, epochs, device, save_path):
  min_train_loss = np.inf

  train_losses = []
  test_losses = []
  train_accuracies = []
  test_accuracies = []

  for epoch in range(epochs):
    train_loss = 0
    test_loss = 0
    train_accuracy = 0
    test_accuracy = 0

    model.train()
    for batch in train_loader:
      image_batch = batch['image'].to(device)
      label_batch = batch['label'].to(device)
      _, label_batch = torch.max(label_batch, 1)

      optimizer.zero_grad()
      y_pred = model(image_batch)
      batch_loss = criterion(y_pred, label_batch)
      batch_loss.backward()
      optimizer.step()

      _, output_labels = torch.max(y_pred, 1)
      correct = label_batch.eq(output_labels).cpu().numpy()
      train_accuracy += sum(correct)
      train_loss += batch_loss.item() * image_batch.size(0)

    average_training_loss = train_loss / len(train_loader.sampler)
    average_training_accuracy = train_accuracy / len(train_loader.sampler)

    average_testing_loss, average_testing_accuracy, _, _ = test_model(
        model, test_loader, 
        criterion, device
        )    
    
    train_losses.append(average_training_loss)
    test_losses.append(average_testing_loss)
    train_accuracies.append(average_training_accuracy)
    test_accuracies.append(average_testing_accuracy)

    print('Epoch: {} \t Train Loss: {:.6f} \t Test Loss: {:.6f} \t Train Accuracy: {:.4f} \t Test Accuracy: {:.4f}'.format(epoch, average_training_loss, average_testing_loss, average_training_accuracy, average_testing_accuracy))
    
    if min_train_loss > average_training_loss :
      print('Model improved - Saving Model')
      min_train_loss = average_training_loss
      torch.save(model.state_dict(), save_path)      
  
  return train_losses, test_losses, train_accuracies, test_accuracies
# Out:
# time: 70.5 ms

# %%
def random_seed():
  torch.manual_seed(0)
  np.random.seed(0)
  random.seed(0)

  if CUDA:
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
# Out:
# time: 4.31 ms

# %%
LAYERS_TO_TRAIN = 'last_layer'
model_name  = 'res2net50_48w_2s'

for fold in FOLDS:
  print("Training with " + fold + " as validation set")

  random_seed()
  train_loader, test_loader = create_train_test_loaders(BATCH_SIZE, test_fold=fold)

  model = all_models[model_name](LAYERS_TO_TRAIN) 

  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=LEARNING_RATE)

  save_path = model_name + '_' + fold + '_weights_' + LAYERS_TO_TRAIN +'.pt'

  train_losses, test_losses, train_accuracies, test_accuracies = train_model(
      model=model, 
      train_loader=train_loader, 
      test_loader=test_loader, 
      optimizer=optimizer, 
      criterion=criterion, 
      epochs=EPOCHS, 
      device=DEVICE,
      save_path=save_path
      )
  
  clear_output(wait=True)
# Out:
# time: 23min 20s

# %% [markdown]
# # Validation and Visualization

# %%
def save_results(average_testing_accuracy, c_report, filename):
  if not os.path.exists("Results"):
    os.makedirs("Results")

  filename = os.path.join("Results", filename)

  with open(filename, 'w') as x_file:
    x_file.write('Test accuracy - ' + str(average_testing_accuracy))
    x_file.write('\n')
    x_file.write('\n')
    x_file.write('Classification report : \n')
    x_file.write(str(c_report))
    x_file.write('\n')
# Out:
# time: 12.3 ms

# %%
def plot_confusion_matrix(y_true, y_pred, filename):
  sb.set(font_scale=1.5)

  if not os.path.exists("Figures"):
    os.makedirs("Figures")

  filename = os.path.join("Figures", filename)
  
  cm = confusion_matrix(y_true, y_pred)

  plt.figure(figsize=(8, 6))
  sb.heatmap(cm, annot=True, fmt="d", linewidths=5, xticklabels=LABELS, yticklabels=LABELS)

  plt.savefig(filename)
  plt.show()
# Out:
# time: 9.55 ms

# %%
for fold in FOLDS:
  _, test_loader = create_train_test_loaders(BATCH_SIZE, test_fold=fold)
  model = all_models[model_name](LAYERS_TO_TRAIN)

  save_path = model_name + '_' + fold + '_weights_' + LAYERS_TO_TRAIN +'.pt'
  model.load_state_dict(torch.load(save_path))

  average_testing_loss, average_testing_accuracy, y_true, y_pred = test_model(
      model=model, 
      test_loader=test_loader, 
      criterion=criterion, 
      device=DEVICE
      )
  
  c_report = classification_report(y_true, y_pred, digits=4, target_names=LABELS)
  filename = model_name + '_' + fold + '_weights_' + LAYERS_TO_TRAIN +'.txt'
  save_results(average_testing_accuracy, c_report, filename)

  print("Confusion matrix for " + fold)
  filename = model_name + '_' + fold + '_weights_' + LAYERS_TO_TRAIN +'.png'
  plot_confusion_matrix(y_true, y_pred, filename)
  print("")
# Out:
# Confusion matrix for fold1
# Confusion matrix for fold2
# Confusion matrix for fold3
# Confusion matrix for fold4
# Confusion matrix for fold5
# time: 9.96 s
